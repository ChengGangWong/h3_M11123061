# %%
import  numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd
# %matplotlib inline
import warnings

# %%
col_names = ['SepalLength',	'SepalWidth','PetalLength',	'PetalWidth']

# %%
#df_data_set = pd.read_csv('/Users/Willie/AirQualityUCI.csv', names=columns)
df=pd.read_csv("Iris_Normalization.csv", header=None,names=col_names)
df#= pd.get_dummies
df.info()
df.isna().sum()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  151 non-null    object
#  1   SepalWidth   151 non-null    object
#  2   PetalLength  151 non-null    object
#  3   PetalWidth   151 non-null    object
# dtypes: object(4)
# memory usage: 4.8+ KB
#               SepalLength         SepalWidth         PetalLength  \
# count                 151                151                 151
# unique                 36                 24                  44
# top     0.194444444444444  0.416666666666667  0.0847457627118644
# freq                   10                 26                  14
#
#                 PetalWidth
# count                  151
# unique                  23
# top     0.0416666666666667
# freq                    28

# %%
#類別型資料轉換成數值標籤
SepalLengthoh = pd.get_dummies(df['SepalLength'],prefix = 'SepalLength',prefix_sep = '/')
df2 = df.drop ('SepalLength',1)
df3 = pd.concat([df2 , SepalLengthoh],axis = 1)
df3
# Out:
# C:\Users\sc121\AppData\Local\Temp\ipykernel_41848\2344125610.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2 = df.drop ('SepalLength',1)
#             SepalWidth         PetalLength          PetalWidth  SepalLength/0  \
# 0           SepalWidth         PetalLength          PetalWidth              0
# 1                0.625  0.0677966101694915  0.0416666666666667              0
# 2    0.416666666666667  0.0677966101694915  0.0416666666666667              0
# 3                  0.5  0.0508474576271186  0.0416666666666667              0
# 4    0.458333333333333  0.0847457627118644  0.0416666666666667              0
# ..                 ...                 ...                 ...            ...
# 146  0.416666666666667   0.711864406779661   0.916666666666667              0
# 147  0.208333333333333   0.677966101694915                0.75              0
# ...

# %%
SepalWidthoh = pd.get_dummies(df['SepalWidth'],prefix = 'SepalWidth',prefix_sep = '/')
df4 = df3.drop ('SepalWidth',1)
df5 = pd.concat([df4 , SepalWidthoh],axis = 1)
df5
# Out:
# C:\Users\sc121\AppData\Local\Temp\ipykernel_41848\1335647963.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df4 = df3.drop ('SepalWidth',1)
#             PetalLength          PetalWidth  SepalLength/0  \
# 0           PetalLength          PetalWidth              0
# 1    0.0677966101694915  0.0416666666666667              0
# 2    0.0677966101694915  0.0416666666666667              0
# 3    0.0508474576271186  0.0416666666666667              0
# 4    0.0847457627118644  0.0416666666666667              0
# ..                  ...                 ...            ...
# 146   0.711864406779661   0.916666666666667              0
# 147   0.677966101694915                0.75              0
# 148   0.711864406779661   0.791666666666667              0
# 149   0.745762711864407   0.916666666666667              0
# 150   0.694915254237288   0.708333333333333              0
#
# ...

# %%
PetalLengthoh = pd.get_dummies(df['PetalLength'],prefix = 'PetalLength',prefix_sep = '/')
df6 = df5.drop ('PetalLength',1)
df7 = pd.concat([df6 , PetalLengthoh],axis = 1)
df7
# Out:
# C:\Users\sc121\AppData\Local\Temp\ipykernel_41848\3863190558.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df6 = df5.drop ('PetalLength',1)
#              PetalWidth  SepalLength/0  SepalLength/0.0277777777777779  \
# 0            PetalWidth              0                               0
# 1    0.0416666666666667              0                               0
# 2    0.0416666666666667              0                               0
# 3    0.0416666666666667              0                               0
# 4    0.0416666666666667              0                               0
# ..                  ...            ...                             ...
# 146   0.916666666666667              0                               0
# 147                0.75              0                               0
# 148   0.791666666666667              0                               0
# ...

# %%
#把PetalWidth當成特徵值
Y= df7.PetalWidth
#刪除PetalWidth將值丟入X當訓練資料
X = df7.drop(columns=['PetalWidth'])


#把PetalWidthoh當成特徵值

#df9 = pd.concat([df8 , PetalWidthoh],axis = 1)
#df9

# %%
from sklearn.cluster import KMeans



kmeansModel = KMeans(n_clusters=3, random_state=46)
clusters_pred = kmeansModel.fit_predict(X)
#KMeans

#kmeans = KMeans(n_clusters= 3 )
#clusters_pred = kmeansModel.fit_predict(X)

# 訓練預測
#train_labels= kmeans.predict(X) 

#測試預測
#test_labels = kmeans.predict(Y)

# %%
#資料的品質
kmeansModel.inertia_
# Out:
# 387.6006517754091

# %%
kmeansModel.cluster_centers_
# Out:
# array([[-1.73472348e-18,  1.94174757e-02,  9.70873786e-03,
#          2.91262136e-02,  1.94174757e-02,  1.94174757e-02,
#          1.94174757e-02,  7.76699029e-02,  5.82524272e-02,
#          1.94174757e-02, -1.73472348e-18,  2.91262136e-02,
#          6.79611650e-02,  3.88349515e-02,  5.82524272e-02,
#          6.79611650e-02,  9.70873786e-03,  4.85436893e-02,
#          3.88349515e-02,  3.88349515e-02,  8.73786408e-02,
#          5.82524272e-02,  1.94174757e-02,  9.70873786e-03,
#          2.91262136e-02,  1.94174757e-02,  9.70873786e-03,
#          9.70873786e-03, -1.73472348e-18,  1.94174757e-02,
#          9.70873786e-03,  9.70873786e-03, -1.73472348e-18,
#          2.91262136e-02,  9.70873786e-03,  9.70873786e-03,
#          9.70873786e-03,  2.91262136e-02,  3.88349515e-02,
#          2.91262136e-02,  7.76699029e-02,  4.85436893e-02,
#          8.73786408e-02,  1.35922330e-01,  9.70873786e-02,
#         -1.38777878e-16, -1.66533454e-16,  1.26213592e-01,
# ...

# %%
from sklearn.cluster import KMeans

#data = list(zip(X_train, y_train))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
def purity(cluster, labels, k, label_set):
    p = np.zeros((k, len(label_set)))
    purity = 0
    for i in range(len(cluster)):
        p[int(cluster[i]), label_set.index(labels[i])] += 1

    purity = sum(np.max(p, axis=1))/len(labels)

    return purity
